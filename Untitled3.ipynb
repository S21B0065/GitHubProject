# %% [markdown]
# <a href="https://colab.research.google.com/github/S21B0065/GitHubProject/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import scipy
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/diabetes.csv')
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0    125.0  33.6
# 1          1.0     85.0           66.0           29.0    125.0  26.6
# 2          8.0    183.0           64.0            NaN    125.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50      1.0
# 1                     0.351   31      NaN
# 2                     0.672   32      1.0
# 3                     0.167   21      NaN
# 4                     2.288   33      1.0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import pandas as pd

# Assuming you have a CSV file named 'data.csv' in your current working directory
df = pd.read_csv('diabetes.csv')

# Now you can use df.describe() and df.head() without encountering a NameError
df.describe()
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.replace(0, np.nan, inplace=True)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50      1.0
# 1                     0.351   31      NaN
# 2                     0.672   32      1.0
# 3                     0.167   21      NaN
# 4                     2.288   33      1.0

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      NaN  33.6
# 1            1.0     85.0           66.0           29.0      NaN  26.6
# 2            8.0    183.0           64.0            NaN      NaN  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            NaN    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      NaN  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            NaN      NaN  30.1
# 767          1.0     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50      1.0
# ...

# %%
df.hist(column='Insulin')
# Out:
# array([[<Axes: title={'center': 'Insulin'}>]], dtype=object)

# %%
#replacing missing values in Insulin column
#with median of that column
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].median())

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0    125.0  33.6
# 1            1.0     85.0           66.0           29.0    125.0  26.6
# 2            8.0    183.0           64.0            NaN    125.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            NaN    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0    125.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            NaN    125.0  30.1
# 767          1.0     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50      1.0
# ...

# %%
df.hist(column='Glucose')
# Out:
# array([[<Axes: title={'center': 'Glucose'}>]], dtype=object)

# %%
#replacing missing values in Insulin column
#with median of that column
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].median())

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0    125.0  33.6
# 1            1.0     85.0           66.0           29.0    125.0  26.6
# 2            8.0    183.0           64.0            NaN    125.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            NaN    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0    125.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            NaN    125.0  30.1
# 767          1.0     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50      1.0
# ...

# %%
#replacing missing values in Insulin column
#with median of that column
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].mean())

# %%
print(df.iloc[[182]])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 182          1.0    117.0           74.0           20.0     23.0  27.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 182                     0.299   21      NaN

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/diabetes.csv')
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0    125.0  33.6
# 1          1.0     85.0           66.0           29.0    125.0  26.6
# 2          8.0    183.0           64.0            NaN    125.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50      1.0
# 1                     0.351   31      NaN
# 2                     0.672   32      1.0
# 3                     0.167   21      NaN
# 4                     2.288   33      1.0

# %%
# Box Plots
fig, axs = plt.subplots(9,1,dpi=95, figsize=(7,17))
i = 0
for col in df.columns:
	axs[i].boxplot(df[col], vert=False)
	axs[i].set_ylabel(col)
	i+=1
plt.show()

# %%
# Identify the quartiles
q1, q3 = np.percentile(df['Insulin'], [25, 75])
# Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = df[(df['Insulin'] >= lower_bound)
				& (df['Insulin'] <= upper_bound)]

# %%
print(clean_data)
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Identify the quartiles
q1, q3 = np.percentile(clean_data['Pregnancies'], [25, 75])
#Calculate the interquartile range
iqr = q3 - q1
# Calculate the lower and upper bounds
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers
clean_data = df[(df['Pregnancies'] >= lower_bound)
				& (df['Pregnancies'] <= upper_bound)]

# %%
print(clean_data)
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
